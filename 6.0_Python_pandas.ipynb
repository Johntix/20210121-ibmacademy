# %% [markdown]
# <img src = "data/logos.png" width = 600, align = "center">
# <br>
# <h1 align=center><font size = 5>Pandi Pandas</font></h1>

# %% [markdown]
# # Premiers pas du Pandas
#
# **pandas** est un package Python permettant de manipuler les données dans des structures simples d'utilisation. Les données sont rangées dans des tableaux et de nombreuses méthodes permettent de
#
# pandas est adapté aux :
#
# - données tabulaires dont les colonnes sont de types hétérogenes comme des tables SQL ou des classeurs excel.
# - séries temporelles.
# - matrices dont les lignes et colonnes sont labellisées.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Structures de données Pandas

# %% [markdown]
# ### Series
#
# Une **Series** est un vecteur de données (lsorte de array Numpy) muni d'un *index* qui étiquette chaque élement du vecteur (tableau associatif).

# %%
calories = pd.Series([314,314,401,"342"])
calories
# Out:
# 0    314
# 1    314
# 2    401
# 3    342
# dtype: object

# %% [markdown]
# Un index qui n'est pas spécifié est remplacé par une numérotation démarrant a 0. On peut considérer l'index et les valeurs comme des attributs de la `Series`. Il s'agit cependant d'objet de types différents :

# %%
calories.values
# Out:
# array([314, 314, 401, '342'], dtype=object)

# %%
type(calories.values)
# Out:
# numpy.ndarray

# %%
calories.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
type(calories.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# Il est préférable d'assigner aux index des valeurs compréhensibles ayant un sens correspondant au contexte :

# %%
fromages = pd.Series([314,314,401,342], 
    index=['Carredelest', 'Babybel', 'Beaufort', 'Bleu'])

fromages
# Out:
# Carredelest    314
# Babybel        314
# Beaufort       401
# Bleu           342
# dtype: int64

# %% [markdown]
# Ces étiquettes ou ` labels` sont les clés d'acces aux valeurs de la `serie`.

# %%
fromages['Babybel']
# Out:
# 314

# %%
fromages[[name.endswith('el') for name in fromages.index]]
# Out:
# Babybel    314
# dtype: int64

# %%
[name.endswith('el') for name in fromages.index]
# Out:
# [False, True, False, False]

# %% [markdown]
# Il reste cependant possible d'utiliser l'indexation par défaut a valeurs numériques :

# %%
fromages[0]
# Out:
# 314

# %% [markdown]
# Les valeurs comme l'index peuvent etre nommés de maniere explicite :

# %%
fromages.name = 'nombre'
fromages.index.name = 'nom'
fromages
# Out:
# nom
# Carredelest    314
# Babybel        314
# Beaufort       401
# Bleu           342
# Name: nombre, dtype: int64

# %% [markdown]
# Les opérations et fonctions mathématiques de Numpy peuvent etre utilisées avec les `series` sans perte de structure :

# %%
np.sqrt(fromages)
# Out:
# nom
# Carredelest    17.720045
# Babybel        17.720045
# Beaufort       20.024984
# Bleu           18.493242
# Name: nombre, dtype: float64

# %% [markdown]
# Les `Series` peuvent etre filtrées par valeur :

# %%
fromages[fromages>400]
# Out:
# nom
# Beaufort    401
# Name: nombre, dtype: int64

# %% [markdown]
# Une `Series` peut etre créée a partir d'un `dict`:

# %%
fromages_dict = {'Carredelest': 314, 'Babybel': 314, 'Beaufort': 401, 'Bleu': 342}
pd.Series(fromages_dict)
# Out:
# Carredelest    314
# Babybel        314
# Beaufort       401
# Bleu           342
# dtype: int64

# %% [markdown]
# La `Series` est alors ordonnées par clé :
# Si une erreur apparait dans l'index Pandas utilisera la valeur `NaN` (not a number) pour les valeurs manquantes.

# %%
fromages2 = pd.Series(fromages_dict, index=['Carredelest', 'Babybel', 'Beaufort', 'Bleu' , 'Comte'])
fromages2
# Out:
# Carredelest    314.0
# Babybel        314.0
# Beaufort       401.0
# Bleu           342.0
# Comte            NaN
# dtype: float64

# %%
fromages2.isnull()
# Out:
# Carredelest    False
# Babybel        False
# Beaufort       False
# Bleu           False
# Comte           True
# dtype: bool

# %% [markdown]
# Plus délicat, les index sont utilisés pour aligner les valeurs lors des opérations entre `Series` :

# %%
fromages + fromages2
# Out:
# Babybel        628.0
# Beaufort       802.0
# Bleu           684.0
# Carredelest    628.0
# Comte            NaN
# dtype: float64

# %% [markdown]
# ### DataFrame
#
# Les données que nous qvons a manipuler sont plus souvent dans des dimensions supérieurs et a chaque *index* correspondront plusieurs colonnes souvent de types différents.
#
# Un `DataFrame` est une struture tabulaire contenant plusieurs colonnes de type `Series`.

# %%
data = pd.DataFrame({'calories':[314,314,401,342, 264, 367],
                     'sodium':[353.5, 238,112, 336, 314, 256],
                     'nom':['Carredelest', 'Babybel', 'Beaufort', 'Bleu' , 'Camembert', 'Cantal']})
data
# Out:
#    calories  sodium          nom
# 0       314   353.5  Carredelest
# 1       314   238.0      Babybel
# 2       401   112.0     Beaufort
# 3       342   336.0         Bleu
# 4       264   314.0    Camembert
# 5       367   256.0       Cantal

# %% [markdown]
# Les colonnes du `DataFrame` peuvent être réordonnées :

# %%
data[['nom', 'calories', 'sodium']]
# Out:
#            nom  calories  sodium
# 0  Carredelest       314   353.5
# 1      Babybel       314   238.0
# 2     Beaufort       401   112.0
# 3         Bleu       342   336.0
# 4    Camembert       264   314.0
# 5       Cantal       367   256.0

# %% [markdown]
# Un `DataFrame` possede un deuxieme index, représentant les colonnes:

# %%
data.columns
# Out:
# Index(['calories', 'sodium', 'nom'], dtype='object')

# %% [markdown]
# On accede alors facilement aux colonnes par l'index ou comme attribut :

# %%
data['calories']
# Out:
# 0    314
# 1    314
# 2    401
# 3    342
# 4    264
# 5    367
# Name: calories, dtype: int64

# %%
data.calories
# Out:
# 0    314
# 1    314
# 2    401
# 3    342
# 4    264
# 5    367
# Name: calories, dtype: int64

# %%
type(data.calories)
# Out:
# pandas.core.series.Series

# %%
type(data[['calories']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A la difference des `Series`, l'acces a une ligne particuliere du `DataFrame` utilisera l'attribut `iloc`.

# %%
data.iloc[3]
# Out:
# calories     342
# sodium       336
# nom         Bleu
# Name: 3, dtype: object

# %% [markdown]
# Il est important de noter que les `Series` obtenues depuis un `DataFrame` sont des **vues** du DataFrame et non une copie. Il faut donc être prudent lors de leurs manipulation.

# %%
valeurs = data.calories
valeurs
# Out:
# 0    314
# 1    314
# 2    401
# 3    342
# 4    264
# 5    367
# Name: calories, dtype: int64

# %%
calories[5] = 0
calories
# Out:
# 0    314
# 1    314
# 2    401
# 3    342
# 5      0
# dtype: object

# %%
data
# Out:
#    calories  sodium          nom
# 0       314   353.5  Carredelest
# 1       314   238.0      Babybel
# 2       401   112.0     Beaufort
# 3       342   336.0         Bleu
# 4       264   314.0    Camembert
# 5       367   256.0       Cantal

# %%
vals = data.calories.copy()
vals[5] = 1000
data
# Out:
#    calories  sodium          nom
# 0       314   353.5  Carredelest
# 1       314   238.0      Babybel
# 2       401   112.0     Beaufort
# 3       342   336.0         Bleu
# 4       264   314.0    Camembert
# 5       367   256.0       Cantal

# %% [markdown]
# Il est possible de créer ou de modifier des colonnes directement :

# %%
data.calories[3] = 145
data
# Out:
# <ipython-input-31-e8685df6f93c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.calories[3] = 145
#    calories  sodium          nom
# 0       314   353.5  Carredelest
# 1       314   238.0      Babybel
# 2       401   112.0     Beaufort
# 3       145   336.0         Bleu
# 4       264   314.0    Camembert
# 5       367   256.0       Cantal

# %%
data['calcium'] = 72.6
data
# Out:
#    calories  sodium          nom  calcium
# 0       314   353.5  Carredelest     72.6
# 1       314   238.0      Babybel     72.6
# 2       401   112.0     Beaufort     72.6
# 3       145   336.0         Bleu     72.6
# 4       264   314.0    Camembert     72.6
# 5       367   256.0       Cantal     72.6

# %% [markdown]
# Si une série est utilisée pour la création d'une colonne, ses valeurs seront placées en fonction fe l'index du DataFrame :

# %%
dispo = pd.Series([0]*4 + [1]*2)
dispo
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# 5    1
# dtype: int64

# %%
data['dispo'] = dispo
data
# Out:
#    calories  sodium          nom  calcium  dispo
# 0       314   353.5  Carredelest     72.6      0
# 1       314   238.0      Babybel     72.6      0
# 2       401   112.0     Beaufort     72.6      0
# 3       145   336.0         Bleu     72.6      0
# 4       264   314.0    Camembert     72.6      1
# 5       367   256.0       Cantal     72.6      1

# %% [markdown]
# Les structures ne possédant pas un index doivent absolument avoir la même longueur que le `DataFrame`:

# %%
mois = ['Jan', 'Fev', 'Mar', 'Avr']
data['mois'] = mois
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-36b1928d2683> in <module>
#       1 mois = ['Jan', 'Fev', 'Mar', 'Avr']
# ----> 2 data['mois'] = mois
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
data['mois'] = ['Jan']*len(data)
data
# Out:
#    calories  sodium          nom  calcium  dispo mois
# 0       314   353.5  Carredelest     72.6      0  Jan
# 1       314   238.0      Babybel     72.6      0  Jan
# 2       401   112.0     Beaufort     72.6      0  Jan
# 3       145   336.0         Bleu     72.6      0  Jan
# 4       264   314.0    Camembert     72.6      1  Jan
# 5       367   256.0       Cantal     72.6      1  Jan

# %% [markdown]
# La méthode `del` peut être utilisée comme dans un `dict` pour supprimer les colonnes :

# %%
del data['mois']
data
# Out:
#    calories  sodium          nom  calcium  dispo
# 0       314   353.5  Carredelest     72.6      0
# 1       314   238.0      Babybel     72.6      0
# 2       401   112.0     Beaufort     72.6      0
# 3       145   336.0         Bleu     72.6      0
# 4       264   314.0    Camembert     72.6      1
# 5       367   256.0       Cantal     72.6      1

# %% [markdown]
# Le dataFrame possède des attributs de même nom que les colonnes et se présentant comme des `ndarray` :

# %%
data.calories
# Out:
# 0    314
# 1    314
# 2    401
# 3    145
# 4    264
# 5    367
# Name: calories, dtype: int64

# %% [markdown]
# ## Importer des données

# %% [markdown]
# Pandas dispose d'un ensemble de fonctions dédiées à l'import des données tabulaires provenant de sources différentes directement sous la forme d'un dataFrame. Ces fonctions  These functions comportent un certain nombre d'options permettant d'indexer, de parser, de faire des itération et de nettoyer automatiquement les données.

# %% [markdown]
# **Chargement d'un format csv**

# %% [markdown]
# Utilisation de la méthode `read_csv` :
# Remarque : Les caractères accentués necessitent un encodage particulier utf-8 ou latin 1 etc...

# %%
mb = pd.read_csv("data/fromage.csv")
mb.head()
# Out:
#   Fromages;calories;sodium;calcium;lipides;retinol;folates;proteines;cholesterol;magnesium
# 0  CarredelEst;314;353.5;72.6;26.3;51.6;30.3;21;7...
# 1     Babybel;314;238;209.8;25.1;63.7;6.4;22.6;70;27
# 2   Beaufort;401;112;259.4;33.3;54.9;1.2;26.6;120;41
# 3       Bleu;342;336;211.1;28.9;37.1;27.5;20.2;90;27
# 4   Camembert;264;314;215.9;19.5;103;36.4;23.4;60;20

# %% [markdown]
# La première ligne est, par défaut, considérée comme contenant les noms des colonnes.
#
# Il est possible de personnaliser le DataFrame en modifiant les paramètres tels que `header`, `names` or `index_col`.

# %%
pd.read_csv("data/fromage.csv", encoding='latin1', header=None).head()
# Out:
#                                                    0
# 0  Fromages;calories;sodium;calcium;lipides;retin...
# 1  CarredelEst;314;353.5;72.6;26.3;51.6;30.3;21;7...
# 2     Babybel;314;238;209.8;25.1;63.7;6.4;22.6;70;27
# 3   Beaufort;401;112;259.4;33.3;54.9;1.2;26.6;120;41
# 4       Bleu;342;336;211.1;28.9;37.1;27.5;20.2;90;27

# %% [markdown]
# `read_csv` est un cas particulier de la méthode `read_table` :

# %%
mb = pd.read_table("data/fromage.csv", sep=';')
mb.head()
# Out:
#       Fromages  calories  sodium  calcium  lipides retinol  folates  \
# 0  CarredelEst       314   353.5     72.6     26.3    51.6     30.3
# 1      Babybel       314   238.0    209.8     25.1    63.7      6.4
# 2     Beaufort       401   112.0    259.4     33.3    54.9      1.2
# 3         Bleu       342   336.0    211.1     28.9    37.1     27.5
# 4    Camembert       264   314.0    215.9     19.5     103     36.4
#
#    proteines  cholesterol  magnesium
# 0       21.0           70       20.0
# 1       22.6           70       27.0
# 2       26.6          120       41.0
# 3       20.2           90       27.0
# 4       23.4           60       20.0

# %% [markdown]
# Dans ce cas, il est possible de personaliser la valeur du séparateur `sep`. On peut, par exemple utiliser une expréssion régulière pour définir un nombre d'espacements variables ce qui, malheureusement, trop fréquent.
#
#     sep='\s+'

# %% [markdown]
# Pour une indexation plus complexe, de type hiérarchique par exemple, il est possible de spécifier l'argument `index_col`.

# %%
mb = pd.read_csv("data/fromage.csv", sep=";", index_col=['calories','Fromages'])
mb.head()
# Out:
#                       sodium  calcium  lipides retinol  folates  proteines  \
# calories Fromages
# 314      CarredelEst   353.5     72.6     26.3    51.6     30.3       21.0
#          Babybel       238.0    209.8     25.1    63.7      6.4       22.6
# 401      Beaufort      112.0    259.4     33.3    54.9      1.2       26.6
# 342      Bleu          336.0    211.1     28.9    37.1     27.5       20.2
# 264      Camembert     314.0    215.9     19.5     103     36.4       23.4
#
#                       cholesterol  magnesium
# calories Fromages
# 314      CarredelEst           70       20.0
#          Babybel               70       27.0
# 401      Beaufort             120       41.0
# 342      Bleu                  90       27.0
# 264      Camembert             60       20.0

# %% [markdown]
# L'argument `skiprows` permet d'exclure certaines lignes du chargement:

# %%
pd.read_csv("data/fromage.csv", sep=';', skiprows=[3,4,6]).head()
# Out:
#       Fromages  calories  sodium  calcium  lipides retinol  folates  \
# 0  CarredelEst       314   353.5     72.6     26.3    51.6     30.3
# 1      Babybel       314   238.0    209.8     25.1    63.7      6.4
# 2    Camembert       264   314.0    215.9     19.5     103     36.4
# 3    Chabichou       344   192.0     87.2     27.9    90.1     36.3
# 4     Chaource       292   276.0    132.9     25.4   116.4     32.5
#
#    proteines  cholesterol  magnesium
# 0       21.0           70       20.0
# 1       22.6           70       27.0
# 2       23.4           60       20.0
# 3       19.5           80       36.0
# 4       17.8           70       25.0

# %% [markdown]
# Ou bien n'importer qu'un nombre limité de lignes avec l'argument `nrows`:

# %%
pd.read_csv("data/fromage.csv", sep=';', nrows=4)
# Out:
#       Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0  CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1      Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2     Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3         Bleu       342   336.0    211.1     28.9     37.1     27.5
#
#    proteines  cholesterol  magnesium
# 0       21.0           70         20
# 1       22.6           70         27
# 2       26.6          120         41
# 3       20.2           90         27

# %% [markdown]
# **ou de créer un découpage selon un pas**

# %%
data_decoupe = pd.read_csv("data/fromage.csv", sep=';',chunksize=5)
i=0
for chunk in data_decoupe : 
    print(chunk.Fromages[i])
    i+=5
# Out:
# CarredelEst
# Cantal
# Coulomniers
# Fr.frais20nat.
# Petitsuisse40
# SaintPaulin

# %% [markdown]
# La plupart des jeux de données sont incomplets, truffés de trous et d'erreurs de saisie. Pandas marque automatiquement cles cellules vides.

# %%
pd.read_csv("data/fromage.csv", sep=";").head(20)
# Out:
#               Fromages  calories  sodium  calcium  lipides retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3    51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1    63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3    54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9    37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5     103     36.4
# 5               Cantal       367   256.0    264.0     28.8    48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9    90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4   116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5    76.4      4.9
# 9                Comte       399    92.0    220.5     32.4    55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6    63.6     21.1
# 11                Edam       327   148.0    272.2     24.7    65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4    56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5   150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0    77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5       ?     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8    64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1    46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5    57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5      90      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80    -9999.0
# 19       35.7           80       46.0

# %% [markdown]
# Pandas a reconnu automatiquement deux champs vides marqués NaN.

# %%
pd.isnull(pd.read_csv("data/fromage.csv", sep=";")).head(20)
# Out:
#     Fromages  calories  sodium  calcium  lipides  retinol  folates  proteines  \
# 0      False     False   False    False    False    False    False      False
# 1      False     False   False    False    False    False    False      False
# 2      False     False   False    False    False    False    False      False
# 3      False     False   False    False    False    False    False      False
# 4      False     False   False    False    False    False    False      False
# 5      False     False   False    False    False    False    False      False
# 6      False     False   False    False    False    False    False      False
# 7      False     False   False    False    False    False    False      False
# 8      False     False   False    False    False    False    False      False
# 9      False     False   False    False    False    False     True      False
# 10     False     False   False    False    False    False    False      False
# 11     False     False   False    False    False    False    False      False
# 12     False     False   False    False    False    False    False      False
# 13     False     False   False    False    False    False    False      False
# 14     False     False   False    False    False    False    False      False
# 15     False     False   False    False    False    False    False      False
# 16     False     False   False    False    False    False    False      False
# 17     False     False   False    False    False    False    False      False
# 18     False     False   False    False    False    False    False      False
# 19     False     False   False    False    False    False    False      False
#
#     cholesterol  magnesium
# 0         False      False
# 1         False      False
# 2         False      False
# 3         False      False
# 4         False      False
# 5         False      False
# 6         False      False
# 7         False      False
# 8         False      False
# 9         False      False
# 10        False      False
# 11        False       True
# 12        False      False
# 13        False      False
# 14        False      False
# 15        False      False
# 16        False      False
# 17        False      False
# 18        False      False
# 19        False      False

# %% [markdown]
# Malheureusement les valeurs abérentes telles que "?" ou "-9999" ne sont pas détéctées et il faut alors spécifier le champ de filtrage avec des règles plus précises avec un argument `na_values` :

# %%
pd.read_csv("data/fromage.csv",sep=";", na_values=['?', -9999]).head(20)
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      NaN     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        NaN
# 19       35.7           80       46.0

# %% [markdown]
# ### Microsoft Excel
#
# Beaucoup de champs professionnels tels que la Finance fonctionnent encore avec des classeurs Excel. Pandas possède une méthode spécifique permettant d'y accéder : `read_excel`. Cependant des dépendances sont parfois nécessaires et doivent être installées en fonction de la version du fichier Excel importé `xlrd` et `openpyxl` (utiliser `pip` ou `easy_install`).

# %%
mb2 = pd.read_excel('data/Canada.xlsx', sheet_name='Canada by Citizenship (2)', header=None)
mb2.head()
# Out:
#            0           1               2     3         4     5   \
# 0        Type    Coverage          OdName  AREA  AreaName   REG
# 1  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 2  Immigrants  Foreigners         Albania   908    Europe   925
# 3  Immigrants  Foreigners         Algeria   903    Africa   912
# 4  Immigrants  Foreigners  American Samoa   909   Oceania   957
#
#                 6    7                   8     9   ...    33    34    35  \
# 0          RegName  DEV             DevName  1980  ...  2004  2005  2006
# 1    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 2  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 3  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 4        Polynesia  902  Developing regions     0  ...     0     0     1
#
#      36    37    38    39    40    41    42
# 0  2007  2008  2009  2010  2011  2012  2013
# 1  2652  2111  1746  1758  2203  2635  2004
# 2   702   560   716   561   539   620   603
# 3  3623  4005  5393  4752  4325  3774  4331
# 4     0     0     0     0     0     0     0
#
# [5 rows x 43 columns]

# %% [markdown]
# D'autres format sont accessibles via Python et peuvent être concertis en DataFrame ce sont les fichiers de type JSON, XML, HDF5, les bdd relationelles ou non, etc...

# %% [markdown]
# ## Fonctions principales de Pandas

# %% [markdown]
# Dans cette dernière partie du Notebook nous allons voir les fonctions clés de Pandas.
# Après le fromage un peu de sport !

# %%
football = pd.read_csv("data/fulldata.csv", index_col="Name")
football.shape
# Out:
# (17588, 52)

# %% [markdown]
# Le choix d'indexer le dataframe par le nom des joueurs peut sembler évident mais il convient de verifier l'unicité.

# %%
football.index.is_unique
# Out:
# False

# %% [markdown]
# En effet certains joueurs ayant changé d'équipe de nombreuses fois y compris lors d'une même année :

# %%
pd.Series(football.index).value_counts()
# Out:
# Felipe              6
# Gabriel             5
# Danilo              5
# Carlos Rodríguez    4
# Roberto             4
#                    ..
# Llorente            1
# Pedro Queirós       1
# Diego Godoy         1
# Caio                1
# Ryan Woods          1
# Name: Name, Length: 17341, dtype: int64

# %%
football.loc['Felipe']
# Out:
#        Nationality National_Position  National_Kit                 Club  \
# Name
# Felipe      Brazil               NaN           NaN             FC Porto
# Felipe      Brazil               NaN           NaN              Udinese
# Felipe      Brazil               NaN           NaN               Chaves
# Felipe      Brazil               NaN           NaN         NY Red Bulls
# Felipe      Brazil               NaN           NaN  Sanfrecce Hiroshima
# Felipe      Brazil               NaN           NaN          Hannover 96
#
#        Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  Height  \
# Name
# Felipe           RCB      28.0   07/01/2016           2021.0      80  185 cm
# Felipe           LCB      30.0   08/31/2015           2017.0      75  188 cm
# Felipe           Sub      33.0   07/04/2016           2017.0      73  189 cm
# Felipe           RDM       8.0   01/27/2015           2022.0      71  171 cm
# Felipe            RF      10.0   01/25/2017           2017.0      71  171 cm
# Felipe           Sub      20.0   07/01/2012           2018.0      70  193 cm
#
#         ... Long_Shots Curve Freekick_Accuracy  Penalties Volleys  \
# Name    ...
# Felipe  ...         41    32                30         47      40
# Felipe  ...         40    49                21         35      19
# Felipe  ...         44    44                39         45      48
# Felipe  ...         70    75                68         65      64
# Felipe  ...         66    63                45         54      67
# Felipe  ...         58    33                31         52      26
#
#        GK_Positioning  GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# Name
# Felipe              9          9          14           11            7
# Felipe              9         11           8            6            5
# Felipe             11         11          11            8           14
# Felipe             14          8           9            9           12
# Felipe              8         16          13            9           13
# Felipe             12         13          14           16           15
#
# [6 rows x 52 columns]

# %% [markdown]
# Peut être faut-il alors combiner des colonnes pour créer un index unique exemple `Name` avec `Club`:

# %%
id = football.index + football.Club
football_2 = football.copy()
football_2.index = id
football_2.head()
# Out:
#                              Nationality National_Position  National_Kit  \
# Cristiano RonaldoReal Madrid    Portugal                LS           7.0
# Lionel MessiFC Barcelona       Argentina                RW          10.0
# NeymarFC Barcelona                Brazil                LW          10.0
# Luis SuárezFC Barcelona          Uruguay                LS           9.0
# Manuel NeuerFC Bayern            Germany                GK           1.0
#
#                                       Club Club_Position  Club_Kit  \
# Cristiano RonaldoReal Madrid   Real Madrid            LW       7.0
# Lionel MessiFC Barcelona      FC Barcelona            RW      10.0
# NeymarFC Barcelona            FC Barcelona            LW      11.0
# Luis SuárezFC Barcelona       FC Barcelona            ST       9.0
# Manuel NeuerFC Bayern            FC Bayern            GK       1.0
#
#                              Club_Joining  Contract_Expiry  Rating  Height  \
# Cristiano RonaldoReal Madrid   07/01/2009           2021.0      94  185 cm
# Lionel MessiFC Barcelona       07/01/2004           2018.0      93  170 cm
# NeymarFC Barcelona             07/01/2013           2021.0      92  174 cm
# Luis SuárezFC Barcelona        07/11/2014           2021.0      92  182 cm
# Manuel NeuerFC Bayern          07/01/2011           2021.0      92  193 cm
#
#                               ... Long_Shots Curve Freekick_Accuracy  \
# Cristiano RonaldoReal Madrid  ...         90    81                76
# Lionel MessiFC Barcelona      ...         88    89                90
# NeymarFC Barcelona            ...         77    79                84
# Luis SuárezFC Barcelona       ...         86    86                84
# Manuel NeuerFC Bayern         ...         16    14                11
#
#                               Penalties Volleys GK_Positioning  GK_Diving  \
# Cristiano RonaldoReal Madrid         85      88             14          7
# Lionel MessiFC Barcelona             74      85             14          6
# NeymarFC Barcelona                   81      83             15          9
# Luis SuárezFC Barcelona              85      88             33         27
# Manuel NeuerFC Bayern                47      11             91         89
#
#                               GK_Kicking  GK_Handling  GK_Reflexes
# Cristiano RonaldoReal Madrid          15           11           11
# Lionel MessiFC Barcelona              15           11            8
# NeymarFC Barcelona                    15            9           11
# Luis SuárezFC Barcelona               31           25           37
# Manuel NeuerFC Bayern                 95           90           89
#
# [5 rows x 52 columns]

# %% [markdown]
# On vérifie :

# %%
pd.Series(football_2.index).value_counts()
# Out:
# Jake WrightSheffield Utd           2
# Lee Jae SungJeonbuk Hyundai        2
# Park Dae HanJeonnam Dragons        2
# Pierrick CrosRed Star FC           2
# Shigeto MasudaAlbirex Niigata      1
#                                   ..
# Zlatan KrizanovićFalkenbergs FF    1
# Andrea CodaPescara                 1
# Sławomir PeszkoLechia Gdańsk       1
# Jhon DuqueMillonarios              1
# Marvin MehlemKarlsruher SC         1
# Length: 17584, dtype: int64

# %% [markdown]
# Toujours pas !

# %%
football_2.loc['Park Dae HanJeonnam Dragons']
# Out:
#                                 Nationality National_Position  National_Kit  \
# Park Dae HanJeonnam Dragons  Korea Republic               NaN           NaN
# Park Dae HanJeonnam Dragons  Korea Republic               NaN           NaN
#
#                                         Club Club_Position  Club_Kit  \
# Park Dae HanJeonnam Dragons  Jeonnam Dragons           Sub      12.0
# Park Dae HanJeonnam Dragons  Jeonnam Dragons           Sub      21.0
#
#                             Club_Joining  Contract_Expiry  Rating  Height  \
# Park Dae HanJeonnam Dragons   01/06/2017           2023.0      65  175 cm
# Park Dae HanJeonnam Dragons   01/01/2017           2020.0      59  183 cm
#
#                              ... Long_Shots Curve Freekick_Accuracy  \
# Park Dae HanJeonnam Dragons  ...         31    29                29
# Park Dae HanJeonnam Dragons  ...          5    14                14
#
#                              Penalties Volleys GK_Positioning  GK_Diving  \
# Park Dae HanJeonnam Dragons         23      34             11          7
# Park Dae HanJeonnam Dragons         10       8             52         64
#
#                              GK_Kicking  GK_Handling  GK_Reflexes
# Park Dae HanJeonnam Dragons           9            8           14
# Park Dae HanJeonnam Dragons          55           54           64
#
# [2 rows x 52 columns]

# %% [markdown]
# Peut être faut-il ajouter la colone "Contract_Expiry".<br>On reprend pour Name comme index.

# %%
football = pd.read_csv("data/fulldata.csv")
football.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    ... Long_Shots Curve Freekick_Accuracy Penalties  Volleys GK_Positioning  \
# 0  ...         90    81                76        85       88             14
# 1  ...         88    89                90        74       85             14
# 2  ...         77    79                84        81       83             15
# 3  ...         86    86                84        85       88             33
# 4  ...         16    14                11        47       11             91
#
#   GK_Diving  GK_Kicking  GK_Handling  GK_Reflexes
# 0         7          15           11           11
# 1         6          15           11            8
# 2         9          15            9           11
# 3        27          31           25           37
# 4        89          95           90           89
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Méthodes de tri
#
# Pandas permet de réorganiser les données avec des méthodes de tri simples.

# %%
football.sort_values(ascending=True,by='Name').head()
# Out:
#                        Name          Nationality National_Position  \
# 6190         A.J. DeLaGarza                 Guam               NaN
# 15621            Aapo Halme              Finland               NaN
# 15863  Aaron Amadi-Holloway                Wales               NaN
# 5800     Aaron Appindangoye                Gabon               NaN
# 15425           Aaron Barry  Republic of Ireland               NaN
#
#        National_Kit             Club Club_Position  Club_Kit Club_Joining  \
# 6190            NaN   Houston Dynamo            RB      20.0   01/13/2017
# 15621           NaN     HJK Helsinki           Sub      16.0   01/01/2016
# 15863           NaN  Oldham Athletic            RS      10.0   01/21/2017
# 5800            NaN  Stade Lavallois           Sub       4.0   06/28/2016
# 15425           NaN       Derry City           LCB      30.0   02/07/2014
#
#        Contract_Expiry  Rating  ... Long_Shots Curve Freekick_Accuracy  \
# 6190            2021.0      69  ...         36    61                55
# 15621           2020.0      57  ...         13    22                21
# 15863           2022.0      57  ...         49    41                45
# 5800            2019.0      69  ...         35    45                39
# 15425           2017.0      58  ...         38    26                29
#
#       Penalties  Volleys GK_Positioning GK_Diving  GK_Kicking  GK_Handling  \
# 6190         52       48             12        13          16            9
# 15621        31       25             12        12          11            6
# 15863        59       28             12        15           7            8
# 5800         48       44              8         6          10           11
# 15425        38       30             10         7          16           15
#
#        GK_Reflexes
# 6190            11
# 15621           14
# 15863            7
# 5800             8
# 15425           13
#
# [5 rows x 53 columns]

# %%
football[['Name','Club','Contract_Expiry']].sort_values(ascending=[True,False], by=['Name', 'Contract_Expiry']).head(20)
# Out:
#                        Name             Club  Contract_Expiry
# 6190         A.J. DeLaGarza   Houston Dynamo           2021.0
# 15621            Aapo Halme     HJK Helsinki           2020.0
# 15863  Aaron Amadi-Holloway  Oldham Athletic           2022.0
# 5800     Aaron Appindangoye  Stade Lavallois           2019.0
# 15425           Aaron Barry       Derry City           2017.0
# 17482          Aaron Bolger  Shamrock Rovers           2017.0
# 15404          Aaron Calver        Sydney FC           2017.0
# 15392         Aaron Chapman       Accrington           2018.0
# 1432        Aaron Cresswell         West Ham           2021.0
# 14052          Aaron Dhondt   Waasl. Beveren           2018.0
# 17315           Aaron Dobbs  Shamrock Rovers           2017.0
# 8352            Aaron Doran     Inverness CT           2018.0
# 15036          Aaron Downes  Cheltenham Town           2023.0
# 15001          Aaron Greene   Bray Wanderers           2017.0
# 13437         Aaron Guillen        FC Dallas           2020.0
# 5544           Aaron Hughes           Hearts           2017.0
# 1554             Aaron Hunt     Hamburger SV           2018.0
# 17387           Aaron Jones     Philadelphia           2020.0
# 11099           Aaron Kovar      Sounders FC           2023.0
# 884            Aaron Lennon          Everton           2018.0

# %% [markdown]
# ## Données manquantes
#
# Les données manquantes sont détectées par Pandas et traitées comme une valeur de type NaN. Ceci est valable pour les cellules vises mais aussi celle égale à None.

# %%
foo = pd.Series([np.nan, -3, None, 'foobar'])
foo
# Out:
# 0       NaN
# 1        -3
# 2      None
# 3    foobar
# dtype: object

# %%
foo.isnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# Les valeurs manquantes peuvent être suprimées.

# %%
data = pd.read_csv("data/fromage.csv", sep=";")
data.head(20)
# Out:
#               Fromages  calories  sodium  calcium  lipides retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3    51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1    63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3    54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9    37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5     103     36.4
# 5               Cantal       367   256.0    264.0     28.8    48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9    90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4   116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5    76.4      4.9
# 9                Comte       399    92.0    220.5     32.4    55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6    63.6     21.1
# 11                Edam       327   148.0    272.2     24.7    65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4    56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5   150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0    77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5       ?     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8    64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1    46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5    57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5      90      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80    -9999.0
# 19       35.7           80       46.0

# %%
data = pd.read_csv("data/fromage.csv",sep=";", na_values=['?', -9999])
data.dropna().head(20) #si je veux le modifier ou l'écraser il fait faire data = data.dropna().head(20)
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
# 20       Petitsuisse40       142    22.0     78.2     10.4     63.4     20.4
# 21         PontlEveque       300   223.0    156.7     23.4     53.0      4.0
# 22            Pyrenees       355   232.0    178.9     28.0     51.5      6.8
# 23           Reblochon       309   272.0    202.3     24.6     73.1      8.1
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 10       20.5           80       13.0
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 19       35.7           80       46.0
# 20        9.4           20       10.0
# 21       21.1           70       22.0
# 22       22.4           90       25.0
# 23       19.7           80       30.0

# %%
data[data.notnull()]
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      NaN     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
# 20       Petitsuisse40       142    22.0     78.2     10.4     63.4     20.4
# 21         PontlEveque       300   223.0    156.7     23.4     53.0      4.0
# 22            Pyrenees       355   232.0    178.9     28.0     51.5      6.8
# 23           Reblochon       309   272.0    202.3     24.6     73.1      8.1
# 24          Rocquefort       370   432.0    162.0     31.2     83.5     13.3
# 25         SaintPaulin       298   205.0    261.0     23.3     60.4      6.7
# 26                Tome       321   252.0    125.5     27.3     62.3      6.2
# 27            Vacherin       321   140.0    218.0     29.3     49.2      3.7
# 28  Yaourtlaitent.nat.        70    91.0    215.7      3.4     42.9      2.9
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        NaN
# 19       35.7           80       46.0
# 20        9.4           20       10.0
# 21       21.1           70       22.0
# 22       22.4           90       25.0
# 23       19.7           80       30.0
# 24       18.7          100       25.0
# 25       23.3           70       26.0
# 26       21.8           80       20.0
# 27       17.6           80       30.0
# 28        4.1           13       14.0

# %% [markdown]
# La méthode `dropna` supprime touts les lignes contenant au moins une valeur manquante.

# %% [markdown]
# Il est possible de spécifier avec l'argumemnt `how='all'`, de ne supprimer que les lignes ne contenant **que des valeurs manquantes**.

# %%
data.dropna(how='all') #pour supprimer les lignes totalement vides
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      NaN     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
# 20       Petitsuisse40       142    22.0     78.2     10.4     63.4     20.4
# 21         PontlEveque       300   223.0    156.7     23.4     53.0      4.0
# 22            Pyrenees       355   232.0    178.9     28.0     51.5      6.8
# 23           Reblochon       309   272.0    202.3     24.6     73.1      8.1
# 24          Rocquefort       370   432.0    162.0     31.2     83.5     13.3
# 25         SaintPaulin       298   205.0    261.0     23.3     60.4      6.7
# 26                Tome       321   252.0    125.5     27.3     62.3      6.2
# 27            Vacherin       321   140.0    218.0     29.3     49.2      3.7
# 28  Yaourtlaitent.nat.        70    91.0    215.7      3.4     42.9      2.9
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        NaN
# 19       35.7           80       46.0
# 20        9.4           20       10.0
# 21       21.1           70       22.0
# 22       22.4           90       25.0
# 23       19.7           80       30.0
# 24       18.7          100       25.0
# 25       23.3           70       26.0
# 26       21.8           80       20.0
# 27       17.6           80       30.0
# 28        4.1           13       14.0

# %% [markdown]
# Ou encore avec l'argument `Thresh` qui spécifie un seuil de valeurs manquantes.

# %%
data.dropna(thresh=4) #il faut qu'il y ait au moins 4 valeurs manquantes pour qu'il supprime la ligne
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      NaN     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
# 20       Petitsuisse40       142    22.0     78.2     10.4     63.4     20.4
# 21         PontlEveque       300   223.0    156.7     23.4     53.0      4.0
# 22            Pyrenees       355   232.0    178.9     28.0     51.5      6.8
# 23           Reblochon       309   272.0    202.3     24.6     73.1      8.1
# 24          Rocquefort       370   432.0    162.0     31.2     83.5     13.3
# 25         SaintPaulin       298   205.0    261.0     23.3     60.4      6.7
# 26                Tome       321   252.0    125.5     27.3     62.3      6.2
# 27            Vacherin       321   140.0    218.0     29.3     49.2      3.7
# 28  Yaourtlaitent.nat.        70    91.0    215.7      3.4     42.9      2.9
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        NaN
# 19       35.7           80       46.0
# 20        9.4           20       10.0
# 21       21.1           70       22.0
# 22       22.4           90       25.0
# 23       19.7           80       30.0
# 24       18.7          100       25.0
# 25       23.3           70       26.0
# 26       21.8           80       20.0
# 27       17.6           80       30.0
# 28        4.1           13       14.0

# %% [markdown]
# Avec l'argument `axis=1` c'est la colonne qui est supprimée !

# %%
data.dropna(axis=1) #le mieux est de ne pas supprimer si on peut (uniquement quand doublons)
# Out:
#               Fromages  calories  sodium  calcium  lipides  proteines  \
# 0          CarredelEst       314   353.5     72.6     26.3       21.0
# 1              Babybel       314   238.0    209.8     25.1       22.6
# 2             Beaufort       401   112.0    259.4     33.3       26.6
# 3                 Bleu       342   336.0    211.1     28.9       20.2
# 4            Camembert       264   314.0    215.9     19.5       23.4
# 5               Cantal       367   256.0    264.0     28.8       23.0
# 6            Chabichou       344   192.0     87.2     27.9       19.5
# 7             Chaource       292   276.0    132.9     25.4       17.8
# 8              Cheddar       406   172.0    182.3     32.5       26.0
# 9                Comte       399    92.0    220.5     32.4       29.2
# 10         Coulomniers       308   222.0     79.2     25.6       20.5
# 11                Edam       327   148.0    272.2     24.7       24.7
# 12            Emmental       378    60.0    308.2     29.4       29.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5       11.1
# 14         Fr.fondu.45       292   390.0    168.5     24.0       16.8
# 15      Fr.frais20nat.        80    41.0    146.3      3.5        8.3
# 16      Fr.frais40nat.       115    25.0     94.8      7.8        7.0
# 17           Maroilles       338   311.0    236.7     29.1       20.4
# 18             Morbier       347   285.0    219.0     29.5       23.6
# 19            Parmesan       381   240.0    334.6     27.5       35.7
# 20       Petitsuisse40       142    22.0     78.2     10.4        9.4
# 21         PontlEveque       300   223.0    156.7     23.4       21.1
# 22            Pyrenees       355   232.0    178.9     28.0       22.4
# 23           Reblochon       309   272.0    202.3     24.6       19.7
# 24          Rocquefort       370   432.0    162.0     31.2       18.7
# 25         SaintPaulin       298   205.0    261.0     23.3       23.3
# 26                Tome       321   252.0    125.5     27.3       21.8
# 27            Vacherin       321   140.0    218.0     29.3       17.6
# 28  Yaourtlaitent.nat.        70    91.0    215.7      3.4        4.1
#
#     cholesterol
# 0            70
# 1            70
# 2           120
# 3            90
# 4            60
# 5            90
# 6            80
# 7            70
# 8           110
# 9           120
# 10           80
# 11           80
# 12          110
# 13           50
# 14           70
# 15           10
# 16           30
# 17           90
# 18           80
# 19           80
# 20           20
# 21           70
# 22           90
# 23           80
# 24          100
# 25           70
# 26           80
# 27           80
# 28           13

# %% [markdown]
# Il est parfois préférable de ne pas supprimer les données mais de les remplacer par une vaaleurs judicieusement choisie : un zéro, une moyenne, une médiane ou une interpollation.

# %%
data.head(20)
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      NaN
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      NaN     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        NaN
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        NaN
# 19       35.7           80       46.0

# %%
data.fillna(0).head(20) #mettre des 0 à la place des NaN
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9      0.0
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5      0.0     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80        0.0
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80        0.0
# 19       35.7           80       46.0

# %% [markdown]
# Ou encore :

# %%
data.fillna(method='bfill').head(20) #prend la valeur de la ligne suivante pour remplir la valeur manquante
# Out:
#               Fromages  calories  sodium  calcium  lipides  retinol  folates  \
# 0          CarredelEst       314   353.5     72.6     26.3     51.6     30.3
# 1              Babybel       314   238.0    209.8     25.1     63.7      6.4
# 2             Beaufort       401   112.0    259.4     33.3     54.9      1.2
# 3                 Bleu       342   336.0    211.1     28.9     37.1     27.5
# 4            Camembert       264   314.0    215.9     19.5    103.0     36.4
# 5               Cantal       367   256.0    264.0     28.8     48.8      5.7
# 6            Chabichou       344   192.0     87.2     27.9     90.1     36.3
# 7             Chaource       292   276.0    132.9     25.4    116.4     32.5
# 8              Cheddar       406   172.0    182.3     32.5     76.4      4.9
# 9                Comte       399    92.0    220.5     32.4     55.9     21.1
# 10         Coulomniers       308   222.0     79.2     25.6     63.6     21.1
# 11                Edam       327   148.0    272.2     24.7     65.7      5.5
# 12            Emmental       378    60.0    308.2     29.4     56.3      2.4
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5    150.5     31.0
# 14         Fr.fondu.45       292   390.0    168.5     24.0     77.4      5.5
# 15      Fr.frais20nat.        80    41.0    146.3      3.5     64.3     20.0
# 16      Fr.frais40nat.       115    25.0     94.8      7.8     64.3     22.6
# 17           Maroilles       338   311.0    236.7     29.1     46.7      3.6
# 18             Morbier       347   285.0    219.0     29.5     57.6      5.8
# 19            Parmesan       381   240.0    334.6     27.5     90.0      5.2
#
#     proteines  cholesterol  magnesium
# 0        21.0           70       20.0
# 1        22.6           70       27.0
# 2        26.6          120       41.0
# 3        20.2           90       27.0
# 4        23.4           60       20.0
# 5        23.0           90       30.0
# 6        19.5           80       36.0
# 7        17.8           70       25.0
# 8        26.0          110       28.0
# 9        29.2          120       51.0
# 10       20.5           80       13.0
# 11       24.7           80       45.0
# 12       29.4          110       45.0
# 13       11.1           50       16.0
# 14       16.8           70       20.0
# 15        8.3           10       11.0
# 16        7.0           30       10.0
# 17       20.4           90       40.0
# 18       23.6           80       46.0
# 19       35.7           80       46.0

# %%
data.fillna(data.mean()).head(20) #remplace la valeur manquante par la moyenne
# Out:
#               Fromages  calories  sodium  calcium  lipides     retinol  \
# 0          CarredelEst       314   353.5     72.6     26.3   51.600000
# 1              Babybel       314   238.0    209.8     25.1   63.700000
# 2             Beaufort       401   112.0    259.4     33.3   54.900000
# 3                 Bleu       342   336.0    211.1     28.9   37.100000
# 4            Camembert       264   314.0    215.9     19.5  103.000000
# 5               Cantal       367   256.0    264.0     28.8   48.800000
# 6            Chabichou       344   192.0     87.2     27.9   90.100000
# 7             Chaource       292   276.0    132.9     25.4  116.400000
# 8              Cheddar       406   172.0    182.3     32.5   76.400000
# 9                Comte       399    92.0    220.5     32.4   55.900000
# 10         Coulomniers       308   222.0     79.2     25.6   63.600000
# 11                Edam       327   148.0    272.2     24.7   65.700000
# 12            Emmental       378    60.0    308.2     29.4   56.300000
# 13  Fr.chevrepatemolle       206   160.0     72.8     18.5  150.500000
# 14         Fr.fondu.45       292   390.0    168.5     24.0   77.400000
# 15      Fr.frais20nat.        80    41.0    146.3      3.5   68.189286
# 16      Fr.frais40nat.       115    25.0     94.8      7.8   64.300000
# 17           Maroilles       338   311.0    236.7     29.1   46.700000
# 18             Morbier       347   285.0    219.0     29.5   57.600000
# 19            Parmesan       381   240.0    334.6     27.5   90.000000
#
#       folates  proteines  cholesterol  magnesium
# 0   30.300000       21.0           70  20.000000
# 1    6.400000       22.6           70  27.000000
# 2    1.200000       26.6          120  41.000000
# 3   27.500000       20.2           90  27.000000
# 4   36.400000       23.4           60  20.000000
# 5    5.700000       23.0           90  30.000000
# 6   36.300000       19.5           80  36.000000
# 7   32.500000       17.8           70  25.000000
# 8    4.900000       26.0          110  28.000000
# 9   13.428571       29.2          120  51.000000
# 10  21.100000       20.5           80  13.000000
# 11   5.500000       24.7           80  26.222222
# 12   2.400000       29.4          110  45.000000
# 13  31.000000       11.1           50  16.000000
# 14   5.500000       16.8           70  20.000000
# 15  20.000000        8.3           10  11.000000
# 16  22.600000        7.0           30  10.000000
# 17   3.600000       20.4           90  40.000000
# 18   5.800000       23.6           80  26.222222
# 19   5.200000       35.7           80  46.000000

# %% [markdown]
# ## Déscription analytique des données
#
# De nombreux outils de calculs statistiques sont disponibles dans Pandas et permettent d'avoir une approche analytique des données.

# %%
data.sum()
# Out:
# Fromages       CarredelEstBabybelBeaufortBleuCamembertCantalC...
# calories                                                    8701
# sodium                                                    6092.5
# calcium                                                   5386.3
# lipides                                                    700.6
# retinol                                                   1909.3
# folates                                                      376
# proteines                                                  584.9
# cholesterol                                                 2163
# magnesium                                                    708
# dtype: object

# %%
data.mean()
# Out:
# calories       300.034483
# sodium         210.086207
# calcium        185.734483
# lipides         24.158621
# retinol         68.189286
# folates         13.428571
# proteines       20.168966
# cholesterol     74.586207
# magnesium       26.222222
# dtype: float64

# %% [markdown]
# Pandas ne comptabilise pas les valeutrs manquantes mais il est possible de modifier son comportement.

# %%
data.mean(skipna=False) #skipna veut dire qu'il laisse les valeurs NaN
# Out:
# calories       300.034483
# sodium         210.086207
# calcium        185.734483
# lipides         24.158621
# retinol               NaN
# folates               NaN
# proteines       20.168966
# cholesterol     74.586207
# magnesium             NaN
# dtype: float64

# %% [markdown]
# Pandas dispose d'une méthode très pratiquepour la description des données :  `describe`:

# %%
data.describe()#en une seul fois on a une visualisation globales de tous les calculs statistiques
# Out:
#          calories      sodium     calcium    lipides     retinol    folates  \
# count   29.000000   29.000000   29.000000  29.000000   28.000000  28.000000
# mean   300.034483  210.086207  185.734483  24.158621   68.189286  13.428571
# std     91.914356  108.678923   72.528882   8.129642   24.364901  11.716081
# min     70.000000   22.000000   72.600000   3.400000   37.100000   1.200000
# 25%    292.000000  140.000000  132.900000  23.400000   52.650000   5.125000
# 50%    321.000000  223.000000  202.300000  26.300000   62.850000   6.550000
# 75%    355.000000  276.000000  220.500000  29.100000   76.650000  21.475000
# max    406.000000  432.000000  334.600000  33.300000  150.500000  36.400000
#
#        proteines  cholesterol  magnesium
# count  29.000000    29.000000  27.000000
# mean   20.168966    74.586207  26.222222
# std     6.959788    28.245755  11.219260
# min     4.100000    10.000000  10.000000
# 25%    17.800000    70.000000  20.000000
# 50%    21.000000    80.000000  25.000000
# 75%    23.400000    90.000000  30.000000
# max    35.700000   120.000000  51.000000

# %% [markdown]
# `describe` peut aussi être appliquée aux données non numériques.

# %%
data.Fromages.describe()
# Out:
# count            29
# unique           29
# top       Camembert
# freq              1
# Name: Fromages, dtype: object

# %% [markdown]
# Méthodes de correlation :

# %%
data.calories.corr(data.calcium)#correlation entre les colones (recherche) plus le chiffre est bas moins il y a de relation plus on s'approche de 1 plus c'est proche
# Out:
# 0.4334000874295368

# %%
data.corr()
# Out:
#              calories    sodium   calcium   lipides   retinol   folates  \
# calories     1.000000  0.447224  0.433400  0.983634 -0.122009 -0.293005
# sodium       0.447224  1.000000  0.005959  0.483344  0.108487  0.100462
# calcium      0.433400  0.005959  1.000000  0.341132 -0.308874 -0.634257
# lipides      0.983634  0.483344  0.341132  1.000000 -0.100329 -0.248391
# retinol     -0.122009  0.108487 -0.308874 -0.100329  1.000000  0.535710
# folates     -0.293005  0.100462 -0.634257 -0.248391  0.535710  1.000000
# proteines    0.885372  0.275998  0.610705  0.809303 -0.090892 -0.320867
# cholesterol  0.961923  0.332994  0.428446  0.955444 -0.166927 -0.328885
# magnesium    0.761878  0.058362  0.689758  0.715964 -0.140845 -0.386002
#
#              proteines  cholesterol  magnesium
# calories      0.885372     0.961923   0.761878
# sodium        0.275998     0.332994   0.058362
# calcium       0.610705     0.428446   0.689758
# lipides       0.809303     0.955444   0.715964
# retinol      -0.090892    -0.166927  -0.140845
# folates      -0.320867    -0.328885  -0.386002
# proteines     1.000000     0.817138   0.790515
# cholesterol   0.817138     1.000000   0.775202
# magnesium     0.790515     0.775202   1.000000

# %% [markdown]
# ## Exportation des données
#
# To comme la méthode read_csv il existe une méthode to_csv qui permet d'exporter un dataframe vers un fichier csv.

# %%
data.to_csv("data2.csv")

# %% [markdown]
# La méthode `to_csv` accepte aussi les argument `sep`, `header`, `index` et bien d'autres

# %% [markdown]
# <hr>
# Copyright &copy; 2020 Hatem & Driss @NEEDEMAND
